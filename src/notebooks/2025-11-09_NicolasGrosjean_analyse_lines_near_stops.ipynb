# %% [markdown]
# 🚌 Projet MDM - Mobilité Durable en Montagne ⛰️
#
# *Author : Nicolas Grosjean*
#
# *Date : 09/11/2025*
#
# **Description :**
#
# Analyses bus data with C2C activity points :
# - Compute distance between them
# - Identify C2C activity points not deserved
# - Make pretty visualisations to share

# %%
# WORKING DIR NEED TO BE SET BEFORE IMPORTING SETTINGS
import os

os.chdir("../..")
print("Working directory set to the root of the project")
# Out:
# Working directory set to the root of the project

# %%
import folium
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, box

from src.settings import EPSG_WEB_MERCATOR, EPSG_WGS84

# %%
isere_code = "38"

# %% [markdown]
# ## Read data

# %%
from src.processors.osm import OSMBusStopsProcessor

# %%
osm_stops_gdf = OSMBusStopsProcessor.fetch(reload_pipeline=False).set_crs(
    EPSG_WGS84
)  # TODO Remove CRS
osm_stops_gdf.loc[:, "source"] = "OSM"
osm_stops_gdf.head()
# Out:
#   gtfs_id navitia_id  osm_id                    name  \
# 0    None       None  135296  Université - IUT-STAPS
# 1    None       None  135930   Hôpital Couple Enfant
# 2    None       None  136570              Cap des H'
# 3    None       None  136597  Place de la Libération
# 4    None       None  137073             Centr'Alp 2
#
#                             description line_gtfs_ids  \
# 0                                  None            []
# 1                                  None            []
# 2  Arrêt de régulation, non commercial.            []
# 3                                  None            []
# 4                                  None            []
#
#                                         line_osm_ids network network_gtfs_id  \
# 0                                          [3922428]  M réso            None
# 1                                 [3333927, 3922430]  M réso            None
# 2                                                 []  M réso            None
# 3  [3031947, 3031948, 3044780, 3044781, 3923550, ...  M réso            None
# 4                                 [8671286, 8671287]  M réso            None
#
#                    geometry  \
# 0  POINT (5.77622 45.19738)
# 1  POINT (5.74231 45.20065)
# 2  POINT (5.68159 45.21695)
# 3  POINT (5.66272 45.20707)
# 4    POINT (5.6043 45.3198)
#
#                                                other source
# 0  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 1  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 2  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 3  {'alt_name': None, 'amenity': None, 'bench': N...    OSM
# 4  {'alt_name': None, 'amenity': None, 'bench': N...    OSM

# %%
activity_gdf = gpd.read_parquet("src/data_2/C2C/depart_topos_stops_isere.parquet")
print(f"{len(activity_gdf)} activity points")
activity_gdf.rename(
    columns={"navitia_id": "Id wp", "name": "Name wp", "nombre_de_depart_de_topo": "nbr_topo"},
    inplace=True,
)
activity_gdf = activity_gdf[["Id wp", "Name wp", "geometry", "nbr_topo"]]
activity_gdf.head()
# Out:
# 577 activity points
#    Id wp                               Name wp                  geometry  \
# 0  38440                        Pierre Blanche  POINT (5.52399 44.88944)
# 1  39041  Alpe d'Huez - Falaises du lac Besson  POINT (6.09444 45.11727)
# 2  39108         Les Arias d'en bas (Mariande)  POINT (6.17616 44.91703)
# 3  39178            Cirque inférieur du Boulon  POINT (5.96136 45.19128)
# 4  39195          Le Bourg-d'Oisans - Commères   POINT (6.08117 45.0272)
#
#    nbr_topo
# 0         3
# 1         5
# 2         1
# 3         1
# 4        11

# %%
area_gdf = gpd.read_file("src/data/transportdatagouv/contour-des-departements.geojson")
area_gdf = area_gdf.set_crs(EPSG_WGS84, allow_override=True)
area_gdf.head()
# Out:
#   code                      nom  \
# 0   01                      Ain
# 1   02                    Aisne
# 2   03                   Allier
# 3   04  Alpes-de-Haute-Provence
# 4   05             Hautes-Alpes
#
#                                             geometry
# 0  POLYGON ((4.78021 46.17668, 4.78024 46.18905, ...
# 1  POLYGON ((3.17296 50.01131, 3.17382 50.01186, ...
# 2  POLYGON ((3.03207 46.79491, 3.03424 46.7908, 3...
# 3  POLYGON ((5.67604 44.19143, 5.67817 44.19051, ...
# 4  POLYGON ((6.26057 45.12685, 6.26417 45.12641, ...

# %%
isere_activity_df = (
    gpd.sjoin(
        activity_gdf.to_crs(EPSG_WGS84),
        area_gdf[area_gdf["code"] == isere_code].to_crs(EPSG_WGS84),
    )
    .loc[:, ["Id wp"]]
    .drop_duplicates()
    .merge(activity_gdf, on="Id wp", how="inner")
)
isere_activity_gdf = gpd.GeoDataFrame(isere_activity_df, geometry="geometry").set_crs(
    EPSG_WGS84
)
print(f"Filter on Isère: keep {len(isere_activity_gdf)} on {len(activity_gdf)}")
# Out:
# Filter on Isère: keep 514 on 577

# %%
tdg_stops_gdf = gpd.read_parquet(
    os.path.join(os.getcwd(), "src/data/transportdatagouv/stops_38.parquet")
)
tdg_stops_gdf.columns = [
    "network_gtfs_id",
    "network",
    "gtfs_id",
    "name",
    "stop_code",
    "description",
    "line_gtfs_ids",
    "geometry",
]
tdg_stops_gdf.loc[:, "source"] = "TDG"
tdg_stops_gdf.head()
# Out:
#                  network_gtfs_id                       network  \
# 0  CARSxREGIONxAIN:Network:1:LOC      REGION - cars Région Ain
# 1  CARSxREGIONxAIN:Network:1:LOC      REGION - cars Région Ain
# 2  CARSxREGIONxAIN:Network:1:LOC      REGION - cars Région Ain
# 3          ARDECHE:Network:1:LOC  REGION - cars Région Ardèche
# 4          ARDECHE:Network:1:LOC  REGION - cars Région Ardèche
#
#                              gtfs_id       name stop_code description  \
# 0  FR:38261:ZE:38367:CARSxREGIONxAIN    La gare   1136154        <NA>
# 1  FR:38055:ZE:38540:CARSxREGIONxAIN     Mairie   1137588        <NA>
# 2  FR:38465:ZE:38541:CARSxREGIONxAIN      Place   1137590        <NA>
# 3          FR:38298:ZE:40822:ARDECHE  Gare SNCF   1023073        <NA>
# 4          FR:38349:ZE:41169:ARDECHE     Mairie   1027195        <NA>
#
#                                        line_gtfs_ids  \
# 0  {'line_id': 'CARSxREGIONxAIN:FlexibleLine:1005...
# 1  {'line_id': 'CARSxREGIONxAIN:FlexibleLine:1005...
# 2  {'line_id': 'CARSxREGIONxAIN:FlexibleLine:1005...
# 3  {'line_id': 'ARDECHE:Line:1000601:LOC', 'line_...
# 4  {'line_id': 'ARDECHE:Line:1000601:LOC', 'line_...
#
#                          geometry source
# 0    POINT (608999.29 5727934.37)    TDG
# 1  POINT (615432.365 5731543.476)    TDG
# 2  POINT (612596.334 5731950.939)    TDG
# 3  POINT (533823.813 5680267.662)    TDG
# 4  POINT (531434.796 5671771.274)    TDG

# %%
from src.processors.c2c import C2CBusStopsProcessor

# %%
c2c_stops_gdf = C2CBusStopsProcessor.fetch(reload_pipeline=False)
c2c_stops_gdf.loc[:, "source"] = "C2C"
c2c_stops_gdf.head()
# Out:
#   gtfs_id              navitia_id osm_id  \
# 0    None  stop_area:OGE:GEN15846   None
# 1    None  stop_area:OGE:GEN15852   None
# 2    None  stop_area:OGE:GEN15850   None
# 3    None  stop_area:OGE:GEN15080   None
# 4    None  stop_area:OGE:GEN13054   None
#
#                                                 name description  \
# 0   Le Haut-Bréda, Pinsot le Village (Le Haut-Bréda)        None
# 1  Le Haut-Bréda, Hot Pic Belle Etoile (Le Haut-B...        None
# 2            Le Haut-Bréda, Chinfert (Le Haut-Bréda)        None
# 3             Le Haut-Bréda, la Piat (Le Haut-Bréda)        None
# 4                     Domène, Domène Mairie (Domène)        None
#
#   line_gtfs_ids line_osm_ids              network network_gtfs_id  \
# 0            []           []  Mobilités M - TouGo            None
# 1            []           []  Mobilités M - TouGo            None
# 2            []           []  Mobilités M - TouGo            None
# 3            []           []  Mobilités M - TouGo            None
# 4            []           []    Mobilités M - Tag            None
#
#                          geometry  \
# 0  POINT (679047.781 5677868.337)
# 1  POINT (678910.858 5678497.283)
# 2  POINT (678788.406 5679655.482)
# 3  POINT (678378.751 5675153.444)
# 4  POINT (649900.998 5653440.123)
#
#                                                other source
# 0  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 1  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 2  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 3  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C
# 4  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C

# %%
all_stops_gdf = pd.concat(
    (osm_stops_gdf, tdg_stops_gdf.to_crs(EPSG_WGS84), c2c_stops_gdf.to_crs(EPSG_WGS84))
)
all_stops_gdf.tail()
# Out:
# /tmp/ipykernel_15682/3211379376.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_stops_gdf = pd.concat(
#     gtfs_id             navitia_id  osm_id  \
# 645    None  stop_area:O38:3226468     NaN
# 646    None  stop_area:O38:3224622     NaN
# 647    None  stop_area:O38:3224623     NaN
# 648    None  stop_area:O38:3224627     NaN
# 649    None  stop_area:O38:3224625     NaN
#
#                                                   name description  \
# 645                                      École (Auris)        None
# 646             Les Égaux (Saint-Pierre-de-Chartreuse)        None
# 647            Gérentière (Saint-Pierre-de-Chartreuse)        None
# 648  École de Saint-Hugues (Saint-Pierre-de-Chartre...        None
# 649          Saint-Hugues (Saint-Pierre-de-Chartreuse)        None
#
#     line_gtfs_ids line_osm_ids             network network_gtfs_id  \
# 645            []           []  Isère - Transisère            None
# 646            []           []  Isère - Transisère            None
# 647            []           []  Isère - Transisère            None
# 648            []           []  Isère - Transisère            None
# 649            []           []  Isère - Transisère            None
#
#                      geometry  \
# 645    POINT (6.0865 45.0459)
# 646  POINT (5.80145 45.31654)
# 647  POINT (5.80912 45.31962)
# 648  POINT (5.80637 45.32302)
# 649  POINT (5.80648 45.32368)
#
#                                                  other source stop_code
# 645  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 646  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 647  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 648  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>
# 649  {'srid': 3857, 'stoparea_id_and_line': [{'line...    C2C      <NA>

# %% [markdown]
# ## Analyse data

# %%
interesting_columns = [
    "Id wp",
    "Name wp",
    "nbr_topo",
    "geometry",
    "osm_id",
    "gtfs_id",
    "name",
    "description",
    "line_osm_ids",
    "line_gtfs_ids",
    "network",
    "distance",
]
activity_stops_gdf = gpd.sjoin_nearest(
    isere_activity_gdf.to_crs(EPSG_WEB_MERCATOR),
    all_stops_gdf.to_crs(EPSG_WEB_MERCATOR),
    how="left",
    distance_col="distance",
)
activity_stops_gdf[interesting_columns].sort_values("distance")
# Out:
#       Id wp                             Name wp  nbr_topo  \
# 196  145472    Corrençon - Foyer de ski de fond         9
# 296  218679                               Claix         4
# 294  212026                   Gresse en Vercors         3
# 383  498794                        Les Cloîtres         1
# 342  280466                 Col de la Charmette         4
# ..      ...                                 ...       ...
# 411  680281                  Cascade des 7 Laux         8
# 71   104267  Clavans le Haut - Hameau du Perron        18
# 267  192778                    Pas de Chabrinel         1
# 123  104584                Le Rivier d'Allemont        48
# 61   104163               Refuge du Promontoire         1
#
#                            geometry        osm_id                 gtfs_id  \
# 196  POINT (614267.184 5625414.299)  4.931381e+07                    None
# 296  POINT (632695.881 5642081.812)  1.803020e+09                    None
# 294  POINT (619739.873 5606131.081)           NaN                    None
# 383  POINT (651692.463 5682037.155)           NaN                    None
# 342   POINT (638983.785 5672336.78)  1.238612e+10                    None
# ..                              ...           ...                     ...
# 411   POINT (674801.61 5654708.703)  1.116080e+09                    None
# 71   POINT (686251.376 5637271.894)           NaN  FR:38237:ZE:6520:ISERE
# 267  POINT (610332.708 5593797.615)           NaN                    None
# 123  POINT (672418.482 5653549.452)           NaN  FR:38527:ZE:1547:ISERE
# 61   POINT (701677.697 5621252.601)           NaN                    None
#
#                                                 name description  \
# 196                                   Hauts Plateaux        None
# 296                                   Les Cimentiers        None
# 294                   Le Village (Gresse-en-Vercors)        None
# 383           Les Cloitres (Saint-Pierre-dEntremont)        None
# 342                              Col de la Charmette        None
# ..                                               ...         ...
# 411                                 Le Collet-Tennis        None
# 71                                          LA COMBE        <NA>
# 267             Carrefour Richardière (Chichilianne)        None
# 123                                         L'EGLISE        <NA>
# 61   Camping la Bérarde (Saint-Christophe-en-Oisans)        None
#
#                                           line_osm_ids  \
# 196                      [3044780, 19169348, 19169352]
# 296  [3931670, 3931671, 18998238, 18998239, 1947519...
# 294                                                 []
# 383                                                 []
# 342                               [18352925, 18352926]
# ..                                                 ...
# 411                                 [7791630, 7791632]
# 71                                                 NaN
# 267                                                 []
# 123                                                NaN
# 61                                                  []
#
#                                          line_gtfs_ids  \
# 196                                                 []
# 296                                                 []
# 294                                                 []
# 383                                                 []
# 342                                                 []
# ..                                                 ...
# 411                                                 []
# 71   {'line_id': 'ISERE:Line:BDO02:LOC', 'line_name...
# 267                                                 []
# 123  {'line_id': 'ISERE:Line:BDO04:LOC', 'line_name...
# 61                                                  []
#
#                         network      distance
# 196           Cars Région Isère      0.868801
# 296                      M réso      1.671476
# 294          Isère - Transisère      2.136405
# 383          Isère - Transisère      2.208040
# 342                      M réso      2.597828
# ..                          ...           ...
# 411           Cars Région Isère   7539.995287
# 71   REGION - cars Région Isère   7698.097443
# 267          Isère - Transisère   7861.490821
# 123  REGION - cars Région Isère   8064.519827
# 61           Isère - Transisère  10150.465282
#
# [536 rows x 12 columns]

# %%
distance_threshold = 5000
too_far_activity_points = activity_stops_gdf[
    activity_stops_gdf["distance"] > distance_threshold
]
print(
    f"{len(too_far_activity_points)} activity points far from any bus stops than {distance_threshold}m"
)
# Out:
# 14 activity points far from any bus stops than 5000m

# %%
too_far_activity_points.loc[:, "lat"] = (
    too_far_activity_points["geometry"].to_crs(EPSG_WGS84).apply(lambda p: p.y)
)
too_far_activity_points.loc[:, "lon"] = (
    too_far_activity_points["geometry"].to_crs(EPSG_WGS84).apply(lambda p: p.x)
)
# Out:
# /data/hdd/Documents/GitHub/mobilite_durable/.venv/lib/python3.13/site-packages/geopandas/geodataframe.py:1981: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /data/hdd/Documents/GitHub/mobilite_durable/.venv/lib/python3.13/site-packages/geopandas/geodataframe.py:1981: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
too_far_activity_points_lon_sorted = too_far_activity_points[
    ["lat", "lon", "Name wp"]
].sort_values("lon")
too_far_activity_points_lon_sorted
# Out:
#            lat       lon                             Name wp
# 267  44.823626  5.482712                    Pas de Chabrinel
# 466  44.801365  5.495224                Bergerie du Jas Neuf
# 498  45.183285  5.965189          Cirque supérieur du Boulon
# 123  45.203082  6.040438                Le Rivier d'Allemont
# 131  44.907750  6.054330                         Valsenestre
# 411  45.210419  6.061846                  Cascade des 7 Laux
# 265  45.208139  6.117582             Barrage de Grand Maison
# 75   45.087469  6.148888                      Col de Sarenne
# 71   45.099960  6.164701  Clavans le Haut - Hameau du Perron
# 318  45.038969  6.185541                 Parking de la Pisse
# 229  45.037722  6.191861               Pont 1090 m (Malaval)
# 194  45.037308  6.202278            Passerelle du Chardillon
# 9    44.979635  6.291625   Contreforts E des Têtes du Replat
# 61   44.998292  6.303278               Refuge du Promontoire

# %%
too_far_activity_points_lon_sorted[2:]["lat"].min()
# Out:
# np.float64(44.907749999995936)

# %%
too_far_activity_points_lon_sorted[2:]["lat"].max()
# Out:
# np.float64(45.21041899999998)

# %%
min_lon_box = 5.9
max_lon_box = 6.31
min_lat_box = 44.9
max_lat_box = 45.3
sub_map_box = box(min_lon_box, min_lat_box, max_lon_box, max_lat_box)

# %%
sub_map_activity_gdf = isere_activity_gdf.cx[min_lon_box:max_lon_box, min_lat_box:max_lat_box]
print(
    f"Filter Isère activities on sub map: keep {len(sub_map_activity_gdf)} on {len(isere_activity_gdf)}"
)
# Out:
# Filter Isère activities on sub map: keep 122 on 514

# %%
sub_map_all_stops_gdf = all_stops_gdf.cx[min_lon_box:max_lon_box, min_lat_box:max_lat_box]
print(f"Filter bus stops on sub map: keep {len(sub_map_all_stops_gdf)} on {len(all_stops_gdf)}")
# Out:
# Filter bus stops on sub map: keep 990 on 22482

# %% [markdown]
# # Visualize

# %% [markdown]
# ## All too far activity points

# %%
# Plot points with bus data far from distance_threshold m

# Add a base OSM map centered on Grenoble
m = folium.Map(location=[45.1885, 5.7245], zoom_start=9, tiles="OpenStreetMap")

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking").add_to(m)

# Add Isère polygon
isere_latlon_coords = [
    (lat, lon)
    for lon, lat in area_gdf[area_gdf["code"] == isere_code]["geometry"]
    .values[0]
    .exterior.coords
]
folium.Polygon(
    locations=isere_latlon_coords,
    color="black",
    weight=3,
    fill_color="black",
    fill_opacity=0.25,
    fill=True,
).add_to(m)

# Add activity markers
columns_to_display = ["Id wp", "Name wp", "nbr_topo"]
folium.GeoJson(
    too_far_activity_points[columns_to_display + ["geometry"]],
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star", color="purple")),
    tooltip=folium.GeoJsonTooltip(fields=columns_to_display),
    popup=folium.GeoJsonPopup(fields=columns_to_display),
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e744534160eb8e3215bec6f9ccd7cd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e744534160eb8e3215bec6f9ccd7cd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e744534160eb8e3215bec6f9ccd7cd7 = L.map(
#                 &quot;map_5e744534160eb8e3215bec6f9ccd7cd7&quot;,
#                 {
#                     center: [45.1885, 5.7245],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e7741288248a3927f57fc8a9b65828c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e7741288248a3927f57fc8a9b65828c.addTo(map_5e744534160eb8e3215bec6f9ccd7cd7);
#
#
#             var tile_layer_f33ab4e15783682aaa8f3e2c09a496e8 = L.tileLayer(
#                 &quot;https://tile.waymarkedtrails.org/hiking/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors | Map style: \u0026copy; \u003ca href=\&quot;https://waymarkedtrails.org\&quot;\u003ewaymarkedtrails.org\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f33ab4e15783682aaa8f3e2c09a496e8.addTo(map_5e744534160eb8e3215bec6f9ccd7cd7);
#
#
#             var polygon_82b6a49db2d4390bddd9821e0c57dce8 = L.polygon(
#                 [[45.61327, 5.62375], [45.61156, 5.62217], [45.60862, 5.62276], [45.60658, 5.62405], [45.60428, 5.62303], [45.60203, 5.62449], [45.6012, 5.62559], [45.59805, 5.63131], [45.58963, 5.63766], [45.58932, 5.63886], [45.58556, 5.64107], [45.58558, 5.64364], [45.58421, 5.64567], [45.57808, 5.64607], [45.57675, 5.64709], [45.57584, 5.6503], [45.57215, 5.65187], [45.5707, 5.65344], [45.56922, 5.65798], [45.56809, 5.65971], [45.56611, 5.66087], [45.56511, 5.66293], [45.56531, 5.66672], [45.56449, 5.66853], [45.56278, 5.66996], [45.56215, 5.67126], [45.56105, 5.67068], [45.55905, 5.67447], [45.55722, 5.67091], [45.55581, 5.6696], [45.55429, 5.67092], [45.55404, 5.67335], [45.55245, 5.67517], [45.55026, 5.67311], [45.54664, 5.67226], [45.54581, 5.67298], [45.54597, 5.67645], [45.54651, 5.67974], [45.54205, 5.68114], [45.54091, 5.68024], [45.54126, 5.6775], [45.54354, 5.67482], [45.54345, 5.67334], [45.53932, 5.67182], [45.53807, 5.66974], [45.53453, 5.67377], [45.53072, 5.67603], [45.52955, 5.6791], [45.52903, 5.68323], [45.52811, 5.6867], [45.52805, 5.69016], [45.52764, 5.69198], [45.52375, 5.69246], [45.52181, 5.69125], [45.52075, 5.69317], [45.51966, 5.6967], [45.51802, 5.70043], [45.51658, 5.702], [45.51414, 5.70218], [45.51337, 5.70367], [45.51238, 5.70361], [45.51001, 5.70174], [45.50919, 5.70053], [45.50818, 5.70117], [45.50912, 5.70597], [45.50919, 5.70796], [45.50747, 5.71259], [45.50637, 5.71349], [45.50233, 5.70984], [45.50109, 5.7124], [45.49945, 5.713], [45.49844, 5.71486], [45.49671, 5.71284], [45.49558, 5.71303], [45.49505, 5.71568], [45.49238, 5.71456], [45.49138, 5.71482], [45.49015, 5.71678], [45.48737, 5.71931], [45.48377, 5.71915], [45.48207, 5.72211], [45.47999, 5.72371], [45.47858, 5.72562], [45.47635

# %%
m.save("no_reachable_activity_points.html")

# %% [markdown]
# ## All data on submap

# %%
# Copy dataframe and add color
activity_columns_to_display = ["Id wp", "Name wp", "nbr_topo"]
sub_map_activity_gdf_to_plot = sub_map_activity_gdf[
    activity_columns_to_display + ["geometry"]
].copy()
sub_map_activity_gdf_to_plot["color"] = "green"
sub_map_activity_gdf_to_plot.loc[
    sub_map_activity_gdf_to_plot["Id wp"].isin(too_far_activity_points["Id wp"]), "color"
] = "purple"
sub_map_activity_gdf_to_plot.head()
# Out:
#    Id wp                                        Name wp  nbr_topo  \
# 1  39041           Alpe d'Huez - Falaises du lac Besson         5
# 2  39108                  Les Arias d'en bas (Mariande)         1
# 3  39178                     Cirque inférieur du Boulon         1
# 4  39195                   Le Bourg-d'Oisans - Commères        11
# 6  39918  Le Vénéon - Vallon de la Selle (ou du Diable)        31
#
#                    geometry  color
# 1  POINT (6.09444 45.11727)  green
# 2  POINT (6.17616 44.91703)  green
# 3  POINT (5.96136 45.19128)  green
# 4   POINT (6.08117 45.0272)  green
# 6  POINT (6.17787 44.96261)  green

# %%
# Plot points with bus data far from distance_threshold m

# Add a base OSM map centered on the box
m = folium.Map(
    location=[(min_lat_box + max_lat_box) / 2, (min_lon_box + max_lon_box) / 2],
    zoom_start=10,
    tiles="OpenStreetMap",
)

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking", control=False).add_to(m)

# Add Isère polygon interscetion with box
isere_latlon_coords = [
    (lat, lon)
    for lon, lat in area_gdf[area_gdf["code"] == isere_code]["geometry"]
    .values[0]
    .intersection(sub_map_box)
    .exterior.coords
]
folium.Polygon(
    locations=isere_latlon_coords,
    color="black",
    weight=3,
    fill_color="black",
    fill_opacity=0.25,
    fill=True,
).add_to(m)

# Add bus markers
source_to_id = {"TDG": "gtfs_id", "OSM": "osm_id", "C2C": "navitia_id"}
for source in sub_map_all_stops_gdf["source"].unique():
    fg = folium.FeatureGroup(name=f"Bus stops from {source}", show=True)
    fields = [source_to_id[source], "name", "network"]
    aliases = [f"<b>Arrêt de bus de {source}</b><br>ID :", "Nom :", "Réseau :"]
    folium.GeoJson(
        sub_map_all_stops_gdf[sub_map_all_stops_gdf["source"] == source][fields + ["geometry"]],
        zoom_on_click=True,
        marker=folium.Marker(icon=folium.Icon(icon="bus", prefix="fa", color="blue")),
        tooltip=folium.GeoJsonTooltip(fields=fields, aliases=aliases),
        popup=folium.GeoJsonPopup(fields=fields, aliases=aliases),
    ).add_to(fg)
    fg.add_to(m)


# Add activity markers
fg = folium.FeatureGroup(name="C2C activity access point", show=True)
aliases = [f"<b>Point d'accès d'activité</b><br>ID :", "Nom :", "Nombre de topos :"]
folium.GeoJson(
    sub_map_activity_gdf_to_plot,
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star")),
    tooltip=folium.GeoJsonTooltip(fields=activity_columns_to_display, aliases=aliases),
    popup=folium.GeoJsonPopup(fields=activity_columns_to_display, aliases=aliases),
    style_function=lambda x: {
        "markerColor": x["properties"]["color"],
    },
).add_to(fg)
fg.add_to(m)

# Add layer control to filter layers
folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e5f480228f178ce5ff3833afb3e1160 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e5f480228f178ce5ff3833afb3e1160&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e5f480228f178ce5ff3833afb3e1160 = L.map(
#                 &quot;map_5e5f480228f178ce5ff3833afb3e1160&quot;,
#                 {
#                     center: [45.099999999999994, 6.105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ffbe091eb1bbb7a4ac73fcacde9ec3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom

# %%
m.save("submap.html")

# %% [markdown]
# # Analyse & visualise - C2C only bus stop

# %%
c2c_only_interesting_columns = [
    "Id wp",
    "Name wp",
    "nbr_topo",
    "geometry",
    "name",
    "network",
    "distance",
]
c2c_only_activity_stops_gdf = gpd.sjoin_nearest(
    isere_activity_gdf.to_crs(EPSG_WEB_MERCATOR),
    c2c_stops_gdf.to_crs(EPSG_WEB_MERCATOR),
    how="left",
    distance_col="distance",
)
c2c_only_activity_stops_gdf[c2c_only_interesting_columns].sort_values("distance")
# Out:
#        Id wp                     Name wp  nbr_topo  \
# 294   212026           Gresse en Vercors         3
# 383   498794                Les Cloîtres         1
# 296   218679                       Claix         4
# 467  1217355      Theys - centre village         1
# 357   338704        Montfort Funiculaire         2
# ..       ...                         ...       ...
# 3      39178  Cirque inférieur du Boulon         1
# 351   315696                      Dionay         1
# 513  1778130                     Eydoche         1
# 513  1778130                     Eydoche         1
# 55    102955  Jardin - Tour de Montléans         1
#
#                            geometry  \
# 294  POINT (619739.873 5606131.081)
# 383  POINT (651692.463 5682037.155)
# 296  POINT (632695.881 5642081.812)
# 467  POINT (667492.918 5668911.073)
# 357  POINT (656689.261 5668649.282)
# ..                              ...
# 3    POINT (663615.448 5651685.199)
# 351  POINT (580982.656 5653574.099)
# 513   POINT (593320.831 5691278.95)
# 513   POINT (593320.831 5691278.95)
# 55   POINT (545759.388 5700722.496)
#
#                                           name              network  \
# 294             Le Village (Gresse-en-Vercors)   Isère - Transisère
# 383     Les Cloitres (Saint-Pierre-dEntremont)   Isère - Transisère
# 296              Claix, les Cimentiers (Claix)    Mobilités M - Tag
# 467                Theys, Theys Écoles (Theys)  Mobilités M - TouGo
# 357    Lumbin, Montfort - Funiculaire (Lumbin)    Mobilités M - Tag
# ..                                         ...                  ...
# 3                          La Ville (Allemond)   Isère - Transisère
# 351             Le Village (Cognin-les-Gorges)   Isère - Transisère
# 513  Barbusse Gare Routière (Bourgoin-Jallieu)         CAPI - Ruban
# 513  Barbusse Gare Routière (Bourgoin-Jallieu)   Isère - Transisère
# 55                        Massonas (Frontonas)   Isère - Transisère
#
#          distance
# 294      2.136405
# 383      2.208040
# 296      4.778016
# 467      4.810536
# 357      5.122381
# ..            ...
# 3    12962.114335
# 351  22081.252975
# 513  24862.726000
# 513  24862.726000
# 55   40853.535536
#
# [528 rows x 7 columns]

# %%
c2c_only_activity_stops_gdf[c2c_only_interesting_columns].sort_values("distance").to_csv(
    "nearest_c2c_bus_stop.csv", index=None
)

# %%
c2c_only_too_far_activity_points = c2c_only_activity_stops_gdf[
    c2c_only_activity_stops_gdf["distance"] > distance_threshold
]
print(
    f"{len(c2c_only_too_far_activity_points)} activity points far from any C2C bus stops than {distance_threshold}m"
)
# Out:
# 64 activity points far from any C2C bus stops than 5000m

# %%
# Plot points with bus data far from distance_threshold m

# Add a base OSM map centered on Grenoble
m = folium.Map(location=[45.1885, 5.7245], zoom_start=9, tiles="OpenStreetMap")

# Add Waymarked Trails hiking layers
folium.TileLayer(tiles="WaymarkedTrails.hiking").add_to(m)

columns_to_display = ["Id wp", "Name wp", "nbr_topo"]
folium.GeoJson(
    c2c_only_too_far_activity_points[columns_to_display + ["geometry"]],
    name="C2C stop areas not merged with Transport Data Gouv",
    zoom_on_click=True,
    marker=folium.Marker(icon=folium.Icon(icon="star", color="purple")),
    tooltip=folium.GeoJsonTooltip(fields=columns_to_display),
    popup=folium.GeoJsonPopup(fields=columns_to_display),
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ee58c0b64f90735305422f0be517630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ee58c0b64f90735305422f0be517630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ee58c0b64f90735305422f0be517630 = L.map(
#                 &quot;map_3ee58c0b64f90735305422f0be517630&quot;,
#                 {
#                     center: [45.1885, 5.7245],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65b4329fabb496ab5eb674b54164831f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65b4329fabb496ab5eb674b54164831f.addTo(map_3ee58c0b64f90735305422f0be517630);
#
#
#             var tile_layer_ce5eb3e6bfed5a2c0434658fe687b337 = L.tileLayer(
#                 &quot;https://tile.waymarkedtrails.org/hiking/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors | Map style: \u0026copy; \u003ca href=\&quot;https://waymarkedtrails.org\&quot;\u003ewaymarkedtrails.org\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce5eb3e6bfed5a2c0434658fe687b337.addTo(map_3ee58c0b64f90735305422f0be517630);
#
#
#         function geo_json_b80e12e619615392ed41928b2ebd04f3_pointToLayer(feature, latlng) {
#             var opts = {
# };
#
#             const iconOptions = {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             const iconRootAlias = L.AwesomeMarkers
#             opts.icon = new iconRootAlias.Icon(iconOptions)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_b80e12e619615392ed41928b2ebd04f3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 click: function(e) {
#                     if (typeof e.target.getBounds === &#x27;function&#x27;) {
#                         map_3ee58c0b64f90735305422f0be517630.fitBounds(e.target.getBounds());
#                     }
#                     else if (typeof e.target.getLatLng === &#x27;function&#x27;){
#                         let zoom = map_3ee58c0b64f90735305422f0be517630.getZoom()
#                         zoom = zoom &gt; 12 ? zoom : zoom + 1
#                         map_3ee58c0b64f90735305422f0be517630.flyTo(e.target.getLatLng(), zoom)
#                     }
#                 }
#             });
#         };
#         var geo_json_b80e12e619615392ed41928b2ebd04f3 = L.geoJson(null, {
#                 onEachFeature: geo_json_b80e12e619615392ed41928b2ebd04f3_onEachFeature,
#
#                 pointToLayer: geo_json_b80e12e619615392ed41928b2ebd04f3_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b80e12e619615392ed41928b2ebd04f3_add (data) {
#             geo_json_b80e12e619615392ed41928b2ebd04f3
#                 .addData(data);
#         }
#             geo_json_b80e12e619615392ed41928b2ebd04f3_a

# %%
m.save("c2c_no_reachable_activity_points.html")
